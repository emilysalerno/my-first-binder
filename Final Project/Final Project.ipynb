# %%
install.packages("nflfastR")
install.packages("readr")
# Out:
# Installing package into ‘/srv/rlibs’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/srv/rlibs’
# (as ‘lib’ is unspecified)

# %%
draft_picks  <- read_csv("https://raw.githubusercontent.com/nflverse/nfldata/master/data/draft_picks.csv")
sc_lines <- read_csv("https://raw.githubusercontent.com/nflverse/nfldata/master/data/sc_lines.csv")
teams  <- read_csv("https://raw.githubusercontent.com/nflverse/nfldata/master/data/teams.csv")
games <- read_csv("https://raw.githubusercontent.com/nflverse/nfldata/master/data/games.csv")
# Out:
# Rows: 12253 Columns: 10
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (7): team, pfr_id, pfr_name, player_id, side, category, position
# dbl (3): season, round, pick
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 4092 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): away_team, home_team, side
# dbl (4): season, week, game_id, line
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 768 Columns: 18
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (14): team, nfl, nfl_team_id, espn, pfr, pfflabel, fo, full, location, s...
# dbl  (4): season, pff, sbr, sbr_wins
#
# ...

# %%
head(games)
# Out:
#   game_id         season game_type week gameday    weekday gametime away_team
# 1 1999_01_MIN_ATL 1999   REG       1    1999-09-12 Sunday  NA       MIN
# 2 1999_01_KC_CHI  1999   REG       1    1999-09-12 Sunday  NA       KC
# 3 1999_01_PIT_CLE 1999   REG       1    1999-09-12 Sunday  NA       PIT
# 4 1999_01_OAK_GB  1999   REG       1    1999-09-12 Sunday  NA       OAK
# 5 1999_01_BUF_IND 1999   REG       1    1999-09-12 Sunday  NA       BUF
# 6 1999_01_SF_JAX  1999   REG       1    1999-09-12 Sunday  NA       SF
#   away_score home_team ⋯ wind away_qb_id home_qb_id away_qb_name
# 1 17         ATL       ⋯ NA   00-0003761 00-0002876 Randall Cunningham
# 2 17         CHI       ⋯ 12   00-0006300 00-0010560 Elvis Grbac
# 3 43         CLE       ⋯ 12   00-0015700 00-0004230 Kordell Stewart
# 4 24         GB        ⋯ 10   00-0005741 00-0005106 Rich Gannon
# 5 14         IND       ⋯ NA   00-0005363 00-0010346 Doug Flutie
# 6  3         JAX       ⋯  8   00-0018441 00-0002110 Steve Young
# ...
